# %%
from model import FairseqQwenAudioModel
from omegaconf import OmegaConf
import warnings
warnings.filterwarnings('ignore')

args = OmegaConf.create()
args.qwen_audio_model_path = "Qwen/Qwen-Audio"

model = FairseqQwenAudioModel.build_model(args, None)
# Out:
# audio_start_id: 155163, audio_end_id: 155164, audio_pad_id: 151851.
# 2025-01-07 13:29:34 | WARNING | transformers_modules.Qwen.Qwen-Audio.83eba550f821f38a12d5003582d9098fe66820c0.modeling_qwen | The model is automatically converting to bf16 for faster inference. If you want to disable the automatic precision, please manually add bf16/fp16/fp32=True to "AutoModelForCausalLM.from_pretrained".
# 2025-01-07 13:29:34 | WARNING | transformers_modules.Qwen.Qwen-Audio.83eba550f821f38a12d5003582d9098fe66820c0.modeling_qwen | Try importing flash-attention for faster inference...
# 2025-01-07 13:29:34 | WARNING | transformers_modules.Qwen.Qwen-Audio.83eba550f821f38a12d5003582d9098fe66820c0.modeling_qwen | Warning: import flash_attn rotary fail, please install FlashAttention rotary to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/rotary
# ...

# %%
model
# Out:
# FairseqQwenAudioModel(
#   (encoder): DummyEncoder()
#   (decoder): DummyDecoder()
#   (model): QWenLMHeadModel(
#     (transformer): QWenModel(
#       (wte): Embedding(155947, 4096)
#       (drop): Dropout(p=0.0, inplace=False)
#       (rotary_emb): RotaryEmbedding()
#       (h): ModuleList(
#         (0-31): 32 x QWenBlock(
#           (ln_1): RMSNorm()
#           (attn): QWenAttention(
#             (c_attn): Linear(in_features=4096, out_features=12288, bias=True)
#             (c_proj): Linear(in_features=4096, out_features=4096, bias=False)
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#           )
#           (ln_2): RMSNorm()
#           (mlp): QWenMLP(
#             (w1): Linear(in_features=4096, out_features=11008, bias=False)
#             (w2): Linear(in_features=4096, out_features=11008, bias=False)
#             (c_proj): Linear(in_features=11008, out_features=4096, bias=False)
#           )
#         )
#       )
#       (ln_f): RMSNorm()
# ...

# %%
audio_url = "assets/audio/1272-128104-0000.flac"
sp_prompt = "<|startoftranscription|><|en|><|transcribe|><|en|><|notimestamps|><|wo_itn|>"
query = f"<audio>{audio_url}</audio>{sp_prompt}"

response = model.generate(query)
repsonse
# Out:
# <audio>assets/audio/1272-128104-0000.flac</audio><|startoftranscription|><|en|><|transcribe|><|en|><|notimestamps|><|wo_itn|>mister quilter is the apostle of the middle classes and we are glad to welcome his gospel<|endoftext|>
